# %% [markdown]
# # IO Tools

# %% [markdown]
# ---

# %% [markdown]
# ### Instructions

# %% [markdown]
# * Answer the following exercises.
# * Most of the exercises require no more than a few lines of code, sometimes only one. You should aim to choose the right methods and find the most elegant solutions for each exercise.
# * Submit your .ipynb file when you are done.

# %% [markdown]
# ---

# %% [markdown]
# ### Documentation

# %% [markdown]
# * [Pandas documentation: "IO Tools"](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html)

# %% [markdown]
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **1.** Copy the following data to your clipboard, then create a DataFrame from it using `read_clipboard()`.
#
#          bar   foo
#     0    4     1
#     1    5     2
#     2    6     3

# %% [markdown]
# **2.** Read `avocado_prices.tsv` into a DataFrame.

# %% [markdown]
# **3.** Read the table from the wikipedia article "List of cities in Italy" into a DataFrame.

# %% [markdown]
# **4.** Read the table `NationalNames` from "us_baby_names.sqlite", and save it to a DataFrame named `us_baby_names`.

# %% [markdown]
# **5.** Using `us_baby_names`, plot a single chart to visualize how many male babies and how many female babies were named Jessie each year.

# %% [markdown]
# ![image.png](attachment:image.png)
